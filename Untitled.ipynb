# %%
import pickle
with open("processed_data.pkl", "rb") as f:
    data = pickle.load(f)
print(data["df"].columns.tolist())
# Out:
# ['api_unii', 'api_smiles', 'dose_mg', 'denominator_unit', 'route', 'primary_dosage_form', 'inactive_ingredients', 'exc_unii_set', 'excipient_list', 'smiles', 'MolWt', 'MolLogP', 'TPSA', 'NumHDonors', 'NumHAcceptors', 'NumRotatableBonds', 'NumAromaticRings', 'NumAliphaticRings', 'RingCount', 'FractionCSP3', 'HeavyAtomCount', 'NumValenceElectrons', 'MolMR', 'LabuteASA', 'BalabanJ', 'BertzCT', 'HallKierAlpha', 'NumSaturatedRings', 'NumHeteroatoms', 'NHOHCount', 'api_descriptors', 'log_dose_mg', 'dose_normalized', 'api_features', 'per_unit_id', 'route_id', 'form_id', 'excipient_ids', 'unii']

# %%
print(data["df"])
# Out:
#          api_unii                                         api_smiles  dose_mg  \
# 0      U3H27498KS                  c1cc(c(c(c1)Cl)Cl)-c2c(N)nc(N)nn2     25.0
# 1      6KY687524K  CCC1=C(C)CN(C1=O)C(=O)NCCc2ccc(cc2)S(=O)(=O)NC...      2.0
# 2      0G389FZZ9M                    C[N+](C)(C)C[C@@H](CC(=O)[O-])O      1.0
# 3      423D2T571U  C#C[C@@]1(CC[C@@]2([H])[C@]3([H])CCc4cc(ccc4[C...     30.0
# 4      U202363UOS     CC(C)OC(=O)C(C)(C)Oc1ccc(cc1)C(=O)c2ccc(cc2)Cl     48.0
# ...           ...                                                ...      ...
# 10235  9242ECW6R0  C/C(=C\Cc1c(c2c(COC2=O)c(C)c1OC)O)/CCC(=O)OCCN...    200.0
# 10236  838F01T721  Cc1c(CCN2CCC(CC2)c3c4ccc(cc4on3)F)c(=O)n5CCCC(...      3.0
# 10237  229809935B          CCC(=O)C(CC(C)N(C)C)(c1ccccc1)c2ccccc2.Cl      5.0
# 10238  O26FZP769L          c1ccc(c(c1)C2=NC(C(=O)Nc3ccc(cc32)Cl)O)Cl      0.5
# 10239  1678OK0E08         COC(=O)[C@H](c1ccccc1)[C@@]2([H])CCCCN2.Cl      5.0
#
# ...

# %%
import pandas as pd
df=pd.read_csv("Data/oral_only.csv")
df["primary_dosage_form"].value_counts()
# Out:
# primary_dosage_form
# TABLET                                            3935
# TABLET, FILM COATED                               2126
# CAPSULE                                           1365
# TABLET, EXTENDED RELEASE                           474
# SOLUTION                                           349
# KIT                                                335
# CAPSULE, EXTENDED RELEASE                          325
# TABLET, FILM COATED, EXTENDED RELEASE              257
# SUSPENSION                                         166
# TABLET, COATED                                     152
# CAPSULE, DELAYED RELEASE                           127
# TABLET, DELAYED RELEASE                             99
# TABLET, ORALLY DISINTEGRATING                       87
# CAPSULE, LIQUID FILLED                              70
# SYRUP                                               52
# POWDER, FOR SUSPENSION                              50
# CAPSULE, GELATIN COATED                             50
# ...
